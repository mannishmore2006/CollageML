# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import load_iris

# %%
# Load the Iris dataset
iris = load_iris()
df = pd.DataFrame(
    data=iris.data,
    columns=iris.feature_names
)
df['species'] = pd.Categorical.from_codes(iris.target, iris.target_names)

# %%
# Scatter Plot
plt.figure(figsize=(8, 5))
plt.title("Scatter Plot: Sepal Length vs Sepal Width")
sns.scatterplot(data=df, x='sepal length (cm)', y='sepal width (cm)', hue='species')
plt.show()

# %%
# Bar Plot
plt.figure(figsize=(8, 5))
df_species_mean = df.groupby('species').mean()
df_species_mean.plot(kind='bar', figsize=(10, 6))
plt.title("Mean Values of Features by Species")
plt.ylabel("Feature Values")
plt.show()
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_17164\540612207.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_species_mean = df.groupby('species').mean()

# %%
# Box Plot
plt.figure(figsize=(10, 6))
sns.boxplot(data=df.drop(columns='species'))
plt.title("Box Plot of Iris Features")
plt.show()

# %%
# Pie Chart
species_counts = df['species'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(species_counts, labels=species_counts.index, autopct='%1.1f%%', colors=['lightblue', 'lightgreen', 'lightcoral'])
plt.title("Proportion of Iris Species")
plt.show()

# %%
# Line Chart
plt.figure(figsize=(10, 5))
for species in df['species'].unique():
    subset = df[df['species'] == species]
    plt.plot(subset.index, subset['petal length (cm)'], label=species)
plt.title("Petal Length of Iris Species")
plt.xlabel("Sample Index")
plt.ylabel("Petal Length (cm)")
plt.legend()
plt.show()
